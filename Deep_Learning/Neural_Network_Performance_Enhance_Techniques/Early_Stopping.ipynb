# %%
pip install pylablib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pylablib
#   Downloading pylablib-1.4.3-cp311-cp311-win_amd64.whl (1.8 MB)
#                                               0.0/1.8 MB ? eta -:--:--
#                                               0.0/1.8 MB 960.0 kB/s eta 0:00:02
#      --                                       0.1/1.8 MB 871.5 kB/s eta 0:00:02
#      --                                       0.1/1.8 MB 1.0 MB/s eta 0:00:02
#      ----                                     0.2/1.8 MB 1.2 MB/s eta 0:00:02
#      -----                                    0.3/1.8 MB 1.2 MB/s eta 0:00:02
#      -----------                              0.5/1.8 MB 2.0 MB/s eta 0:00:01
#      ------------------                       0.8/1.8 MB 2.6 MB/s eta 0:00:01
#      -----------------------                  1.0/1.8 MB 3.0 MB/s eta 0:00:01
#      -----------------------                  1.1/1.8 MB 2.6 MB/s eta 0:00:01
#      -----------------------------------      1.6/1.8 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.8/1.8 MB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from pylablib) (1.24.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from pylablib) (1.10.1)
# Requirement already satisfied: pandas in c:\users\manth\appdata\roaming\python\python311\site-packages (from pylablib) (2.2.3)
# Collecting rpyc (from pylablib)
#   Downloading rpyc-6.0.1-py3-none-any.whl (74 kB)
#                                               0.0/74.6 kB ? eta -:--:--
#      ---------------------------------------- 74.6/74.6 kB ? eta 0:00:00
# Requirement already satisfied: numba in c:\programdata\anaconda3\lib\site-packages (from pylablib) (0.57.0)
# Collecting pyft232 (from pylablib)
#   Downloading pyft232-0.12.tar.gz (16 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyvisa>=1.6 (from pylablib)
#   Downloading pyvisa-1.15.0-py3-none-any.whl (179 kB)
#                                               0.0/179.2 kB ? eta -:--:--
#      ------                                   30.7/179.2 kB ? eta -:--:--
#      ----------------------------------     163.8/179.2 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 179.2/179.2 kB 1.6 MB/s eta 0:00:00
# Collecting pyserial (from pylablib)
#   Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
#                                               0.0/90.6 kB ? eta -:--:--
#      -------------------------------          71.7/90.6 kB ? eta -:--:--
#      -------------------------------          71.7/90.6 kB ? eta -:--:--
#      -------------------------------------- 90.6/90.6 kB 737.1 kB/s eta 0:00:00
# Collecting pyusb (from pylablib)
#   Downloading pyusb-1.3.1-py3-none-any.whl (58 kB)
#                                               0.0/58.5 kB ? eta -:--:--
#      ---------------------------------------- 58.5/58.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pyqt5>=5.9 in c:\programdata\anaconda3\lib\site-packages (from pylablib) (5.15.7)
# Collecting pyqtgraph (from pylablib)
#   Downloading pyqtgraph-0.13.7-py3-none-any.whl (1.9 MB)
#                                               0.0/1.9 MB ? eta -:--:--
#      -------                                  0.4/1.9 MB 11.2 MB/s eta 0:00:01
#      ---------                                0.5/1.9 MB 7.3 MB/s eta 0:00:01
#      --------------                           0.7/1.9 MB 7.5 MB/s eta 0:00:01
#      --------------                           0.7/1.9 MB 7.5 MB/s eta 0:00:01
#      --------------                           0.7/1.9 MB 7.5 MB/s eta 0:00:01
#      -------------------------------------    1.8/1.9 MB 7.5 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 6.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.9/1.9 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: PyQt5-sip<13,>=12.11 in c:\programdata\anaconda3\lib\site-packages (from pyqt5>=5.9->pylablib) (12.11.0)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\manth\appdata\roaming\python\python311\site-packages (from pyvisa>=1.6->pylablib) (4.13.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\programdata\anaconda3\lib\site-packages (from numba->pylablib) (0.40.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->pylablib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pylablib) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manth\appdata\roaming\python\python311\site-packages (from pandas->pylablib) (2025.2)
# Collecting plumbum (from rpyc->pylablib)
#   Downloading plumbum-1.9.0-py3-none-any.whl (127 kB)
#                                               0.0/128.0 kB ? eta -:--:--
#      -------------------------------------- 128.0/128.0 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->pylablib) (1.16.0)
# Requirement already satisfied: pywin32 in c:\programdata\anaconda3\lib\site-packages (from plumbum->rpyc->pylablib) (305.1)
# Building wheels for collected packages: pyft232
#   Building wheel for pyft232 (setup.py): started
#   Building wheel for pyft232 (setup.py): finished with status 'done'
#   Created wheel for pyft232: filename=pyft232-0.12-py3-none-any.whl size=19376 sha256=0011ee4fecaab9dddcbc6d4460f321ec1fbdef2686978cbd132a20247bf68eaa
#   Stored in directory: c:\users\manth\appdata\local\pip\cache\wheels\02\0a\25\7765d57d376bf0786c1e0523590263e9b3481e78aaa1851eb4
# Successfully built pyft232
# Installing collected packages: pyserial, pyvisa, pyusb, pyqtgraph, plumbum, rpyc, pyft232, pylablib
# Successfully installed plumbum-1.9.0 pyft232-0.12 pylablib-1.4.3 pyqtgraph-0.13.7 pyserial-3.5 pyusb-1.3.1 pyvisa-1.15.0 rpyc-6.0.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pyserial-miniterm.exe and pyserial-ports.exe are installed in 'C:\Users\manth\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyvisa-info.exe and pyvisa-shell.exe are installed in 'C:\Users\manth\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts rpyc_classic.exe and rpyc_registry.exe are installed in 'C:\Users\manth\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import tensorflow as tf
import numpy as pd
import pandas as pd
# from pylab import rcParam
import warnings
# from mlxtend import plot_decision_region
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout , Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\manth\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
X, y = make_circles(n_samples=100 , noise=0.1, random_state=1 )
df  = X , y

# %%
sns.scatterplot(data=X,y , X= X[:,0], y= X[:,1])
sns.scatterplot(data=X_train_scaled, x=X_train_scaled[:,0], y=X_train_scaled[:,1])
# Out:
#   Cell In[5], line 1
#     sns.scatterplot(data=X,y , X=X[:,0], y=X[:,1])
#                                                  ^
# SyntaxError: positional argument follows keyword argument
