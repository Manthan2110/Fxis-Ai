# %% [markdown]
# # Credict Card Fruad Detection

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the dataset
df = pd.read_csv('creditcard_2023.csv')

# %%
df.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
df.tail()
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 568625 -0.370393  0.189694 -0.938153  ...  0.167503  0.419731  1.288249
# 568626 -0.016935 -0.147733  0.483894  ...  0.031874  0.388161 -0.154257
# 568627 -0.070958 -0.019997 -0.122048  ...  0.140788  0.536523 -0.211100
# 568628  0.580568 -0.207723  0.893527  ... -0.060381 -0.195609 -0.175488
# 568629 -0.347613 -0.340814  0.253971  ...  0.534853 -0.291514  0.157303
#
#              V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
#distribution of legit traansction and fruad transcation
df['Class'].value_counts()
# Out:
# 0    284315
# 1    284315
# Name: Class, dtype: int64

# %% [markdown]
# # In this dataset

# %% [markdown]
# ### Class = 0 --> Legit Transaction

# %% [markdown]
# ### Class = 1 --> Fraud Transaction

# %%
#Separate Data for Analysis
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (284315, 31)

# %%
#Statistical measures of data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean      12026.313506
# std        6929.500715
# min          50.120000
# 25%        6034.540000
# 50%       11996.900000
# 75%       18040.265000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count    284315.000000
# mean      12057.601763
# std        6909.750891
# min          50.010000
# 25%        6074.640000
# 50%       12062.450000
# 75%       18033.780000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
#compare the value of both class
df.groupby('Class').mean()
# Out:
#                   id        V1        V2        V3        V4        V5  \
# Class
# 0      142442.987714  0.505761 -0.491878  0.682095 -0.735981  0.338639
# 1      426186.012286 -0.505761  0.491878 -0.682095  0.735981 -0.338639
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.435088  0.491234 -0.144294  0.585522  ... -0.179851 -0.10964
# 1     -0.435088 -0.491234  0.144294 -0.585522  ...  0.179851  0.10964
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.014098 -0.010255  0.130107 -0.061847 -0.071052 -0.214002 -0.102024
# 1      0.014098  0.010255 -0.130107  0.061847  0.071052  0.214002  0.102024
#
#              Amount
# Class
# 0      12026.313506
# 1      12057.601763
#
# [2 rows x 30 columns]

# %% [markdown]
# # UnderSampling

# %% [markdown]
# ### Build a sample dataset for simliar distribution of Legit & Fraud Transaction.

# %% [markdown]
# ### Number of Fraud Transaction --> 492

# %%
##legit_sample = legit.sample(n=492)

# %% [markdown]
# ### Concating two dataframes

# %%
##new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
##new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 216050  140329.0 -0.810941 -4.858027 -1.864581  2.574220 -2.088573  0.133007
# 82031    59209.0 -0.946024  0.754324  1.727620  0.693752  0.306980 -0.509008
# 204762  135437.0 -1.412455  2.284040 -1.577869 -1.646252  1.322297 -1.330159
# 50487    44512.0 -1.298894  1.225182  1.114799 -0.213046  1.289151 -1.264462
# 232969  147390.0  0.521433 -2.841418 -1.742302  0.453598 -0.140805  2.049435
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 216050  1.304571 -0.331732  1.111510  ...  1.080891  0.046391 -1.181621
# 82031   0.805728 -0.076353 -0.701190  ...  0.103467  0.334860  0.095383
# 204762  1.860116 -0.600979  1.058498  ... -0.047403  0.718469 -0.298352
# 50487   0.430055 -0.924419 -0.856060  ...  0.718587 -0.395691 -0.729595
# 232969  0.168956  0.427573  0.847506  ...  0.074907 -1.215081 -0.115812
#
# ...

# %%
##new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
##new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
##new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93306.878049  0.166897  0.034659 -0.007674  0.008820 -0.104120
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.033431  0.017882  0.017183  0.086949  ... -0.007983 -0.028126
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.024140 -0.022182  0.004287  0.011673  0.024372  0.005863 -0.010534
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       89.127459
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Spiliting data into Features & Targets

# %%
X = df.drop(columns='Class', axis=1)
Y = df['Class']

# %%
print(X)
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %%
print(Y)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 568625    1
# 568626    1
# 568627    1
# 568628    1
# 568629    1
# Name: Class, Length: 568630, dtype: int64

# %% [markdown]
# ## Split the data into Training data & Testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (568630, 30) (454904, 30) (113726, 30)

# %%
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (568630,) (454904,) (113726,)

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Logistics Regression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\manth\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Accuracy Score

# %%
# accuracy on traiining data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on Training data :" ,training_data_accuracy )
# Out:
# Accuracy on Training data : 0.9952099783690624

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test data : ', test_data_accuracy)
# Out:
# Accuracy score on Test data :  0.9955067442801119
